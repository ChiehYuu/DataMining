# %%
from nba_api.stats.static import players
from nba_api.stats.endpoints import shotchartdetail
from nba_api.stats.endpoints import playercareerstats
from nba_api.stats.endpoints import playerindex
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Fetch the list of NBA players
nba_players = players.get_players()

# %%
player_name = "LeBron James"

# Get the player's ID
player_id = [player['id'] for player in nba_players if player['full_name'] == player_name][0]

# Fetch the player's basic info
player_info = players.find_player_by_id(player_id)

# %%
player_career = playercareerstats.PlayerCareerStats(player_id=player_id)

# %%
player_career_df = player_career.get_data_frames()[0]
player_career_json = player_career.get_json()

# %%
player_career_df
# Out:
#     PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE
# 0        2544   2003-04        00  1610612739               CLE        19.0  \
# 1        2544   2004-05        00  1610612739               CLE        20.0
# 2        2544   2005-06        00  1610612739               CLE        21.0
# 3        2544   2006-07        00  1610612739               CLE        22.0
# 4        2544   2007-08        00  1610612739               CLE        23.0
# 5        2544   2008-09        00  1610612739               CLE        24.0
# 6        2544   2009-10        00  1610612739               CLE        25.0
# 7        2544   2010-11        00  1610612748               MIA        26.0
# 8        2544   2011-12        00  1610612748               MIA        27.0
# 9        2544   2012-13        00  1610612748               MIA        28.0
# 10       2544   2013-14        00  1610612748               MIA        29.0
# ...

# %%
index = playerindex.PlayerIndex(league_id='00', season='2022-23')

# %%
season_id = [season for season in player_career_df['SEASON_ID']]

# %%
season = player_career_df[player_career_df['SEASON_ID'] == season_id[0]]

# %%
season['TEAM_ABBREVIATION'].tolist()
# Out:
# ['CLE']

# %%
season['TEAM_ID'].tolist()
# Out:
# [1610612739]

# %%
import json
json.loads(player_career_json)
# Out:
# {'resource': 'playercareerstats',
#  'parameters': {'PerMode': 'Totals', 'PlayerID': 2544, 'LeagueID': None},
#  'resultSets': [{'name': 'SeasonTotalsRegularSeason',
#    'headers': ['PLAYER_ID',
#     'SEASON_ID',
#     'LEAGUE_ID',
#     'TEAM_ID',
#     'TEAM_ABBREVIATION',
#     'PLAYER_AGE',
#     'GP',
#     'GS',
#     'MIN',
#     'FGM',
#     'FGA',
#     'FG_PCT',
#     'FG3M',
#     'FG3A',
#     'FG3_PCT',
#     'FTM',
#     'FTA',
#     'FT_PCT',
#     'OREB',
#     'DREB',
#     'REB',
#     'AST',
#     'STL',
#     'BLK',
#     'TOV',
#     'PF',
#     'PTS'],
#    'rowSet': [[2544,
#      '2003-04',
#      '00',
#      1610612739,
#      'CLE',
#      19.0,
#      79,
#      79,
#      3120.0,
#      622,
#      1492,
#      0.417,
#      63,
#      217,
#      0.29,
#      347,
#      460,
#      0.754,
#      99,
#      333,
#      432,
#      465,
#      130,
#      58,
#      273,
#      149,
#      1654],
#     [2544,
#      '2004-05',
#      '00',
# ...
